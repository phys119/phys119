# %% [markdown]
# # Lab 09 – Radiation Shielding I

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT:</strong> In the MARKDOWN cell below, fill in your name, your student number, and your partner&rsquo;s name.
# </div>

# %% [markdown]
# - Your name: ..
# - Your student number: ..
# - Partner's name: ..

# %%
# %reset -f
import numpy as np
import data_entry2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Learning Goals
#
# - Reflect on experimental results.
# - Scale graph axes to linearize exponential data.
# - Practice fitting models to your data and extracting relevant parameters.
#
# <div style="border:1px solid #888; padding:8px 12px; margin:8px 0;">
# <strong>Experimental goal:</strong> Find the radiation attenuation coefficient, μ, of the paper shielding used in this lab to attenuate low-energy (soft) X-rays, allowing you to predict how much material would be needed to reduce the radiation count-rate by a specific factor.</div>
#
# <br>To accomplish this experimental goal, you will need to:
#
# - Produce a high-quality set of measurements of the decay rate as a function of the number of sheets of paper shielding.
# - Use your analysis toolkit to assess and comment on the quality of the fit between your data and model.
# - Determine the parameters of the exponential decay model describing your experiment, so that you will be able to make a prediction: given a specific number of sheets of paper shielding, what count-rate will be observed?

# %% [markdown]
# **Suggested timeline**
# - 0h00-0h30: Introduction to the lab, familiarization
# - 0h30-1h15: Round 1 data collection. Multitask while doing this so that you are also working on analysis steps such as creating graphs. Check in with other groups and reflect on where there are opportunities to improve your data collection strategies.
# - 1h15-2h00: Complete the initial analysis including finding the best fit and determining the attenuation coefficient (μ) with uncertainty from the slope. Continue to collect data throughout, using your improved data collection strategies. Continue to check in with other groups and reflect on your own results as you go.
# - 2h00-2h30: Plan and perform further improvements. Continue to check in with other groups.
# - 2h30-2h50: Summary of results

# %% [markdown]
# ## Familiarization

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT:</strong> Familiarize yourself with the equipment, collect a small pilot data set consisting of four measurements, and then based on these measurements plan and justify your measurement strategy.
#
# - The Lab 09 Technical Manual on Canvas provides an overview of the equipment, a review of the physics model, and a review of determining uncertainties for this experiment
# - When planning your measurement strategy, estimate an actual time that it will take to complete your measurements (How many measurements total? How much time for each?) and leave yourself sufficient time for your analysis.
# </div>

# %% [markdown]
# ## Data, analysis, observations and reflections

# %% [markdown]
# <div style="background-color:#fff8e1; border-left:5px solid #f9a825; padding:12px 16px; border-radius:4px; margin:8px 0;">
# &#9888;&#65039; <strong>Important!</strong> Record the source ID since you will collect additional data in Lab 10.  &#9888;&#65039;</div>

# %% [markdown]
# Source ID: ..

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT:</strong>
# Engage in the process of executing your measurement and analysis plan. Assess the model validity from your fit and then, if it is valid, extract the numerical parameters for your model, including uncertainties. If it isn't, refine your model and fitting approach such that you can still determine a reliable attenuation coefficient, $\mu$.
#
# <p><br><strong>Tips:</strong>
#
# 1. <strong>Multitask!</strong> Data collection takes a long time this week.
#
# 1. <strong>Use a semilog plot of $\ln(R)$ vs $x$ (number of sheets of paper) for a high-quality set of measurements to determine how well the relationship between count-rate and thickness can be described by the exponential relationship.</strong> Use the Two Parameter Analytic Fit Equations (Prelab 09) to find the best fit and help you extract the desired quantities and their uncertainties.
#
# 1. <strong>Record all of your raw measurements, the number of counts (N) and the exact time (t) over which the counts were recorded.</strong> This will help you calculate your uncertainties correctly and may help to debug problems.
#
# 1. <strong>Record round number in your data spreadsheet</strong> so you can use a single data collection spreadsheet while also keeping track of in which round your data were collected.
#
# 1. <strong>Plot as you go,</strong> both linear-linear (the regular linear-y vs linear-x scatter plot which shows the exponential decay) and semilog (Ln-y vs linear-x with y error bars). This will allow you to keep an eye out for interesting features as you take measurements, allowing you to refine your measurement plan as you go (don't forget to note any changes to your plan).
#
# 1. <strong>Start fitting your data after collecting a handful of data points in round 1.</strong> Multitask your data collection and analysis throughout.
#
# 1. <strong>Go through the typical Compare, Summarize, Reflect and Plan to Improve steps regularly throughout the lab</strong> (multitask during data collection). Discuss your results and reflect in your notebook as you go. Check in regularly with other nearby groups to see if they are noticing features in the data different from yours (note these discussions/comparisons in your lab notebook).
# </div>

# %% [markdown]
# *Include the round number in your data table to help you identify which round of data collection each row corresponds to.*

# %%
# We included the round number in your data table so you can
# identify which round of data collection each row corresponds to

data_entry2.sheet("lab09_data")
# Out:
# Creating undo file
# Sheet name: lab09_data.csv
# ...

# %% [markdown]
# ## Summary of results

# %% [markdown]
# <div style="background-color:#fff8e1; border-left:5px solid #f9a825; padding:12px 16px; border-radius:4px; margin:8px 0;">
# &#9888;&#65039; <strong>Important!</strong> Please sign your source back in before you leave. &#9888;&#65039;</div>

# %% [markdown]
# # Submit
#
# Steps for submission:
#
# 1. Click: Run => Run_All_Cells
# 2. Read through the notebook to ensure all the cells executed correctly and without error.
# 3. File => Save_and_Export_Notebook_As->HTML
# 4. Inspect your html file
# 5. Upload the HTML document to the lab submission assignment on Canvas.

# %%
# The following function will display tables based on the data currently
# stored in your data_entry2 spreadsheets. Please do not modify this cell.
data_entry2.display_sheets()
# Out:
# 'lab09_data.csv'
#       Round_Number      x      N      t  del_t
# Units               units  units  units  units
# 0                1
# 1                1

# %% [markdown]
# # Lab 08: RC circuits II

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT 0:</strong> In the MARKDOWN cell below, fill in your name, your student number, and your partner&rsquo;s name.
# </div>

# %% [markdown]
# - Your name: ..
# - Your student number: ..
# - Partner's name: ..

# %% [markdown]
# <div style="background-color:#ffe8e8; border-left:5px solid #cc0000; padding:12px 16px; border-radius:4px; margin:8px 0;">
# <strong><span style="color:#cc0000;">Before proceeding:</span></strong> Run the code cell immediately below using <code>Shift+Enter</code>, the <code>&#9654;</code> button in the toolbar, or <em>Run &rarr; Run Selected Cells</em>. This cell clears the Python environment and imports the packages needed for today's lab.
# </div>

# %%
# %reset -f
import data_entry2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Learning Goals
#
# - Continue using a range of strategies to improve an overall data set
# - Continue using of scatter plots, residuals plots, and chi-squared to inform improvements or draw conclusions
# - Practicing use of the analytical solution for best fit slope
#
# <div style="border:1px solid #888; padding:8px 12px; margin:8px 0;">
# <strong>Experimental goal:</strong> A comparison between a high-precision determination of the capacitance of your capacitor from the slope of a $\tau$ versus $R$ graph and the capacitance measured directly using a capacitance meter.</div>
#
# ## Summary of this lab
#
# - We will use an analytic expression for the best fit from the prelab of a model function to your  τ vs R data.
# - You can add to your data set from last lab if you are using the same capacitor as last lab.
#
# <div style="background-color:#fff8e1; border-left:5px solid #f9a825; padding:12px 16px; border-radius:4px; margin:8px 0;">
# &#9888;&#65039; <strong>Important!</strong> Double-check that the number on your capacitor this lab matches the one you recorded last week. If it doesn’t, you cannot combine new Lab 08 data with your previous Lab 07 data. &#9888;&#65039;</div>

# %% [markdown]
# ## PART A - INTRO

# %% [markdown]
# Please consult the Lab 07 instructions and prelab for any necessary reminders about the physics background and experimental setup.
#
# We will spend a few minutes reviewing material from the prelab.

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; (Optional) PROMPT A:</strong> Your notes from this part in the MARKDOWN cell below.
# </div>

# %% [markdown]
# ## PART B - FAMILIARIZATION & UNCERTAINTY DISCUSSION

# %% [markdown]
# Discussion about the procedure for making the time and voltage measurements for a specific location along the curve:
#
# - Placement order of the cursors
# - Zooming in and out on the voltage and time axes

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT B:</strong> With your partner, discuss and record details about two or more ways that you plan to improve your measurement techniques for new data collected today. Be specific.</div>

# %% [markdown]
# ## PART C - START OF DATA COLLECTION

# %% [markdown]
# We are treating this lab as a continuation of last week, with the expectation that you will collect 5-6 new, well measured data points. New data collected todata can be added to your existing Lab 07 data set, with the following exceptions:
#
# - If you completed the catch-up lab for the previous lab or are using a different capacitor from last week, you will need to start your data collection from the beginning.
# - If your discussions during Part B revealed that you made mistakes in your uncertainty estimates, you should re-measure those points today.
#
# Having data from last week will not save you any time, but will provide you with a slightly larger data set as you head into Part D.
#
# Note: The resistances should be considered to have uncertainties of 1%.

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT C:</strong> Collect 5-6 new, well measured data points and combine them with your Lab 07 data, if appropriate. Ensure you describe your measurement strategy, including justifying how you determined uncertainties.
# </div>

# %% [markdown]
# ## PART D - INITIAL ANALYSIS

# %% [markdown]
# <div style="background-color:#fff8e1; border-left:5px solid #f9a825; padding:12px 16px; border-radius:4px; margin:8px 0;">
# &#9888;&#65039; <strong>Important!</strong> You do not need <code>fit_plot</code> at all today. This analytical solution will give you the slope and y-intercept information for your best fit, which will correspond to the minimized chi-squared. &#9888;&#65039;</div>

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT D:</strong> In the CODE and MARKDOWN cells below, perform an analysis of your data set, while recording relevant notes as you go.
#
# - Use the analytical solution to minimizing chi-squared to find the slope and uncertainty that correspond to the best fit (minimized chi-squared).
# - Add a model to your scatter plot and make a residuals plot. Make use of your residuals plot to verify that you have the best possible fit. If there is a trend in your residuals, you may wish to consider using a revised model as part of your improvements
# - Use the analytical solution equation to determine the uncertainty in your slope, and then use your slope and uncertainty to determine the capacitance and its uncertainty.
# - Take the time to interpret how good your fit is using your residuals graph and chi-squared.
# - Measure the capacitance directly using the capacitance meter by unhooking your capacitor and taking it to the back bench for to measure. Treat the standard instrumental uncertainty (68% confidence interval) as 1.5% of the value displayed on the capacitance meter.
# - Make a quantitative comparison (t-score) between the capacitance determined from your oscilloscope data and the value measured using the capacitance meter on the back bench.
# </div>

# %% [markdown]
# ## PART E - REFLECTION AND IMPROVEMENTS

# %% [markdown]
# <div style="border:1px solid #888; padding:8px 12px; margin:8px 0;">
# <p><strong>Questions to ask yourself when you are trying improve your experimental results in PHYS 119:</strong></p>
# <ul>
# <li>Could the quality of the <em>individual data points</em> be improved? Could relative uncertainties be reduced? Could uncertainty estimates be performed more precisely? Are there suspicious data points that should be investigated more closely?</li>
# <li>Could the quality of the <em>overall data set</em> be improved by filling in gaps, increasing the range, or exploring interesting features more closely?</li>
# <li>Are there <em>regions in the data</em> where the model doesn't describe the data well? Do the data behave as expected at extreme values?</li>
# <li>Does the <em>model</em> make sense with respect to physical laws? What effects would incorrect model assumptions have on the data?</li>
# <li>Could the <em>quality of the fit</em> be critiqued more closely? What sort of information can be drawn from residuals, chi-squared, and uncertainties in fit parameters? If there are competing models, how can these tools be used to determine which model best describes the data?</li>
# <li>Could the <em>model</em> be improved? Does it seem like the model would benefit from adding additional parameters?</li>
# <li>What can you learn from the work of other groups?</li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT E:</strong> Reflect on your Part D results and then propose, justify and carry out some improvements with 5-6 additional new data points or revisions of existing data points, which may include revisiting the analysis cycle above. If you feel that you have done a good job in characterizing your uncertainties, you can focus your efforts on adding these new data points to your existing data set. In the box below we provide some questions you can ask yourself as consider how to improve your experimental results.
# </div>

# %% [markdown]
# ## PART F - SUMMARY OF RESULTS

# %% [markdown]
# <div style="background-color:#ffe8e8; border-left:5px solid #cc0000; padding:12px 16px; border-radius:4px; margin:8px 0;">
# <strong><span style="color:#cc0000;">Before leaving:</span></strong> Please unhook all of your wires return them to the blue container, so that everything is ready for the next section. Leave the power cords plugged into the back of the power supply and oscilloscope.
# </div>

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT F:</strong> In the MARKDOWN cell below, summarize your key results from Labs 07 and 08 (including how your understanding of C evolved), any major improvements you made and whether they were successful, whether you achieved the experimental goal, and what you would investigate next.
# </div>

# %% [markdown]
# # Submit
#
# Steps for submission:
#
# 1. Click: Kernel => Restart_Kernel_and_Run_All_Cells
# 1. Read through the notebook to ensure all the cells executed correctly and without error.
# 1. File => Save_and_Export_Notebook_As => HTML
# 1. Inspect your downloaded html document
# 1. Upload the HTML document to the prelab submission assignment on Canvas.

# %%
# The following function will display tables based on the data currently
# stored in your data_entry2 spreadsheets. Please do not modify this cell.
data_entry2.display_sheets()

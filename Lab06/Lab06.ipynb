# %% [markdown]
# # Lab 06 - Ohm's Law II

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT 0:</strong> In the MARKDOWN cell below, fill in your name, your student number, and your partner&rsquo;s name.
# </div>

# %% [markdown]
# - Your name:
# - Your student number:
# - Partner's name:

# %% [markdown]
# <div style="background-color:#ffe8e8; border-left:5px solid #cc0000; padding:12px 16px; border-radius:4px; margin:8px 0;">
# <strong><span style="color:#cc0000;">Before proceeding:</span></strong> Run the code cell immediately below using <code>Shift+Enter</code>, the <code>&#9654;</code> button in the toolbar, or <em>Run &rarr; Run Selected Cells</em>. This cell clears the Python environment and imports the packages needed for today's lab.
# </div>

# %%
# %reset -f
import data_entry2
import numpy as np
import matplotlib.pyplot as plt
import fit_plot

# When exporting to html, first change the False below to True, and then "Restart Kernel and Run All Cells"
fit_plot.set_html_export(False)

# %% [markdown]
# ## Learning Goals
#
# - Practice using scatter and residuals plots to inform improvements or draw conclusions
# - Practice including a model in a scatter plot.
# - Practice estimating uncertainty in slope
#
# <div style="border:1px solid #888; padding:8px 12px; margin:8px 0;">
# <strong>Determine the best-fitting slopes to $V$ ($y$-axis) versus $I$ ($x$-axis) data for a resistor and for a light bulb, and then evaluate the degree to which these devices obey Ohm’s Law.
# </div>

# %% [markdown]
# ## Summary of this lab
#
# - You will use a new tool from today's invention activity, along with the model-fitting techniques from the prelab, to determine a precise slope and uncertainty for your $V$ ($y$-axis) versus $I$ ($x$-axis) from last week’s data, allowing you to report a precisely determined resistance for your resistor.
# - Perform new measurements and a similar analysis for a light bulb.

# %% [markdown]
# ## Part A - Grading feedback, intro & learning activities
# *We will continue to deepen your understanding regarding residuals with an invention activity and a brief tutorial on using a new statistic for goodness-of-fit testing.*

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; (Optional) PROMPT A:</strong> Your notes from this part in the MARKDOWN cell below.
# </div>

# %% [markdown]
# ## Part B - Revisit the fit to last week's data

# %% [markdown]
# In this section you will revisit your Lab 05 data to improve your best-fitting line using the interactive fitting widget with the new statistic parameter enabled (see Lab 06 - demo notebook)

# %% [markdown]
# ### *Part B.1 - Copy in your Lab 05 data*

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT B.1:</strong> Use the CODE cell below to copy your Lab 05 data into your Lab 06 notebook. See the comments for a discussion of the notation used for the function <code>data_entry2.sheet_copy(..)</code>
# </div>

# %%
# Run this cell to copy your lab 05 data into this notebook
'''
If you collected more than one round of data in Lab 05
update "lab05_round1" to the name of your final data set spreadsheet.

Let's break down the notation "../Lab05/lab05_round1":
- The ".." means, go up to one higher level folder, 
  thus "../Lab05/your_lab05_data" is telling Python to 
  go up one folder level and then into your Lab05 folder 
  to find the spreadsheet file you want to copy
'''

data_entry2.sheet_copy("../Lab05/lab05_round1", "copy-lab05_round1")

# %% [markdown]
# ### *Part B.2 - Fit your Lab 05 data again, using the new statistic from today's invention activity*
# Use a linear model as you did in Lab 05.

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT B.2:</strong> In the CODE and MARKDOWN cells below, fit your Lab 05 data with help from the new statistic from today's invention.
#     <ol>
#         <li>Fit your data from Lab 05 again to improve your best-fitting line. Do so using the new statistic from today's invention in <code>fit_plot.line(..)</code> as a guide for finding the best-possible fit.</li>
#         <li>Create a spreadsheet using <code>data_entry2</code> containing all trials of your slope (m), y-intercept (b) and corresponding value of the new statistic from today's invention activity to record your minimization process.</li>
#         <li>Using the methods detailed in the Lab 06 demo notebook, calculate the uncertainty in the slope by using the new statistic from today's invention.</li>
#         <li>Make sure to report your new best slope (with uncertainty) and y-intercept.</li>
#     </ol>
# </div>

# %% [markdown]
# ### *Part B.3 - Make a scatterplot and residual plot*

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT B.3:</strong> In the CODE cells below, build properly-labelled scatter and residuals plots. Use your new best-fitting linear model and the code from Section 4 of the Lab 06 demo notebook (two code cells). You should be able to copy the code from these cells directly from the Lab 06 demo notebook and then update the user variables in Cell 1---such as your variable names, slope  and intercept---to match your new best-fitting model that you found in Part B.2 above.
# </div>

# %% [markdown]
# ### *Part B.4 - Report your results and reflect*

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT B.4:</strong> Before moving on, take the time to report you updated findings in the MARKDOWN cell below, using the following guiding questions. Use the CODE cell below to perform any relevant calculations.
#     <ul>
#         <li>What is your revised best estimate of the resistance of your resistor, including uncertainty?</li>
#         <li>What value did you get for the new statistic? How does your residuals graph look? What can you conclude about how well the model describes the data? What was this model?</li>
#     </ul>
# </div>

# %%
# Use this cell for any relevant calculations

# %% [markdown]
# ## Part C -  Familiarize Part I (Build the electric circuit)

# %% [markdown]
# <div style="background-color:#ffe8e8; border-left:5px solid #cc0000; padding:12px 16px; border-radius:4px; margin:8px 0;">
# <strong><span style="color:#cc0000;">Important! </span></strong> Do not turn on the power supply or multimeters until the instructions say to do so.
# </div>

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT C:</strong> Use the Lab 06 Technical Manual on Canvas to help you build your circuit. Record any observations that you make during this process in the MARKDOWN cell below.
# </div>

# %% [markdown]
# ## Part D - Familiarize Part II (Develop your measurement plan)

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT D:</strong> Use the Lab 06 Technical Manual on Canvas to help you familiarize yourself with operating your circuit. Explore the circuit's behaviour. In the MARKDOWN cells below, record your observations. Develop your measurement plan with your partner and then record below any updates to your measurement plan from Lab 05.
# </div>

# %% [markdown]
# ## Part E - Measure, Analyze, Compare, Reflect

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT E:</strong> In the CODE and MARKDOWN cells below, execute your measurement plan and use your updated analysis approach that uses the goodness-of-fit measure from today's invention.
#
# - Create a new spreadsheet in one of the CODE cells below for this week’s light bulb data.
# - Collect current and voltage measurements for the light bulb, which should include uncertainties as you go. Also make sure to record the supply voltage, $V_s$ used for each data point.
# - Use the `fit_plot.line` interactive fitting widget, with the new goodness-of-fit measure enabled, to fit your data: $V$ (y-data) vs $I$ (x-data). Find the slope and its uncertainty for the best-fit line predicted by Ohm’s law. Revisit Part B.2 above if you need a reminder of how to find slope uncertainty.
# - How linear are your light bulb data from Lab 06 as compared to your data from Lab 05? Would you conclude that both of these devices are ohmic? By this question we asking if they both demonstrate the relationship between voltage and current predicted by Ohm's Law. Discuss your results from your bulb data with other groups and make some notes on your comparisons (the shapes of your $V$ versus $I$ graph, as well as the slope value).
# </div>

# %% [markdown]
# ## Part F - Create your scatter plot with your best-fit model and a residuals graph for your best data set

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT F:</strong> In the CODE cells below, build a properly-labelled scatter plot for the bulb data with your new best-fitting linear model and a residuals graph using the code from Section 4 of the Lab 06 demo notebook (similar to what you did for Part B.3 above). You should be able to copy the code in from the Lab 06 demo notebook directly and then update slope and intercept to match your new best-fitting model.
# </div>

# %% [markdown]
# ## Part G - Plan improvements

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT G:</strong> Discuss with your lab partner possible paths for improving the quality of your overall data set. Consider what you learned from making comparisons with other groups as well. In the MARKDOWN cells below, discuss two improvements that would be realistic for you to execute, and have good potential to improve the quality of your data set. Justify your two improvements and how you would expect them to improve your overall results.
# </div>

# %% [markdown]
# ## Part H - Execute Improvements, Compare, Summarize, Reflect (if you have time)

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT H:</strong> If you have time, execute one or both of these improvements and then discuss how they proved to be successful or unsuccessful.
# <br><br>
# <strong>Important!</strong> If you choose to change the range on one or both multimeters as an improvement, you will need to collect an entirely new data set since you should not mix data sets if the range of either multimeter has changed.
# </div>

# %% [markdown]
# ## Part I - Summary of results

# %% [markdown]
# <div style="background-color:#e3f2fd; border-left:5px solid #1976d2; padding:10px 14px; border-radius:4px; margin:8px 0;">
# <strong>&#128221; PROMPT I:</strong> In the MARKDOWN, summarize your key results from Labs 05 and 06 (including how your understanding of R₁ evolved), any major improvements you made and whether they were successful, whether you achieved the experimental goal, and what you would investigate next.
# </div>

# %% [markdown]
# <div style="background-color:#ffe8e8; border-left:5px solid #cc0000; padding:12px 16px; border-radius:4px; margin:8px 0;">
# <strong><span style="color:#cc0000;">Disconnect the circuit before you leave:</span></strong>
# <ol>
#     <li>Turn the power supply off</li>
#     <li>Turn the multimeters off by turning their large central knob to OFF</li>
#     <li>Disassemble the circuit and put all the components back where you found them.</li>
# </ol>
# </div>

# %% [markdown]
# # Submit
#
# Steps for submission:
#
# 1. Update `fit_plot.set_html_export(False)` to `fit_plot.set_html_export(True)` so that the html export of all of your plots works correctly
# 2. Click: Kernel => Restart_Kernel_and_Run_All_Cells
# 3. Read through the notebook to ensure all the cells executed correctly and without error.
# 4. File => Save_and_Export_Notebook_As => HTML
# 5. Inspect your downloaded html document
# 6. Upload the HTML document to the lab submission assignment on Canvas.

# %%
data_entry2.display_sheets()

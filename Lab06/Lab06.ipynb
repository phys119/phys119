# %% [markdown]
# # Lab 06 - Ohm's Law II

# %% [markdown]
# *Edit this cell and provide the information requested:*
# - Your name:
# - Your student number:
# - Partner's name:

# %%
# %reset -f
import numpy as np
import data_entry2
import matplotlib.pyplot as plt
import fit_plot
# %matplotlib widget

# %%
######################## FIT_PLOT.LINE TROUBLESHOOTING ########################

# Follow the instructions below ONLY in case a graph returned by 
# 'fit_plot.line' is not responding (or looks unusual).


####### INSTRUCTIONS #######

# 1: Save your notebook.
# 2: Write down your best-fitting values (they will get erased after running the code below).
# 3: Uncomment the code below.

#### start of code ####
# import os
# notebook_path = os.environ['JPY_SESSION_NAME']
# notebook_filename = os.path.splitext(os.path.basename(notebook_path))[0]
# os.system('rm .' + notebook_filename + '-*')
#### end of code ####

# 4: Run this cell.
# 5: /!\ Comment out the code you just uncommented out. /!\
# 6: Click on 'Kernel --> Restart Kernel and Clear Outputs of All Cells'.
# 7: Save your notebook again.
# 8: Run your notebook as usual.

# %% [markdown]
# ## Part A - Grading feedback, intro & learning activities

# %% [markdown]
# *(Optional) Your notes on anything discussed during this part.*

# %% [markdown]
# ## Part B - Revisit the fit to last week's data

# %% [markdown]
# ## Part C -  Familiarize Part I (Build your circuit)

# %% [markdown]
# ## Part D - Familiarize Part II (Explore)

# %% [markdown]
# ## Part E - Measure, Analyze, Reflect

# %% [markdown]
# ## Part F - Improvements

# %% [markdown]
# ## Part G - Create your scatter plot and residuals graph

# %% [markdown]
# ## Summary of results

# %% [markdown]
# # Submit
#
# Steps for submission:
#
# 1. Click: Run => Run_All_Cells
# 2. Read through the notebook to ensure all the cells executed correctly and without error.
# 3. File => Save_and_Export_Notebook_As->HTML
# 4. Inspect your exported html
# 5. Upload the HTML document to the lab submission assignment on Canvas.

# %%
display_sheets()
